# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
SPOTIPY_CLIENT_ID='e18fafeb60a949d2a9b7d1efccabe69a'
SPOTIPY_CLIENT_SECRET='739bbbed49864382a64a64ccd64ecdcc'
#SPOTIPY_REDIRECT_URI='your-app-redirect-url'

# %%
auth_manager = SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
artist_name = 'Justin Biber' #'Led Zeppelin'

# %% [markdown]
# # Searching Artist

# %%
artists = sp.search(q='artist:'+artist_name,type='artist', limit=10)

# %%
artists
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=artist%3AJustin+Biber&type=artist&offset=0&limit=10',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#     'followers': {'href': None, 'total': 71540268},
#     'genres': ['canadian pop', 'pop'],
#     'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#     'id': '1uNFoZAHBGtllmzznpCI3s',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb8ae7f2aaa9817a704a87ea36',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab676161000051748ae7f2aaa9817a704a87ea36',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f1788ae7f2aaa9817a704a87ea36',
#       'width': 160}],
#     'name': 'Justin Bieber',
#     'popularity': 90,
#     'type': 'artist',
#     'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kKPuJwVrBVJyFBDSzx19t'},
#     'followers': {'href': None, 'total': 8},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/4kKPuJwVrBVJyFBDSzx19t',
#     'id': '4kKPuJwVrBVJyFBDSzx19t',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e893990cf1bf27d6aafdcc40',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02593450df44a7589fde776ba0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e893990cf1bf27d6aafdcc40',
#       'width': 64}],
#     'name': 'Justin Biberon',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:4kKPuJwVrBVJyFBDSzx19t'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/7fbq53hVW39miuOCYFROd3'},
#     'followers': {'href': None, 'total': 794},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/7fbq53hVW39miuOCYFROd3',
#     'id': '7fbq53hVW39miuOCYFROd3',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb403f98e389fb290daa9b84c8',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174403f98e389fb290daa9b84c8',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178403f98e389fb290daa9b84c8',
#       'width': 160}],
#     'name': 'Justin Biber',
#     'popularity': 21,
#     'type': 'artist',
#     'uri': 'spotify:artist:7fbq53hVW39miuOCYFROd3'}],
#   'limit': 10,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 3}}

# %%
artists['artists']['items']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#   'followers': {'href': None, 'total': 71540268},
#   'genres': ['canadian pop', 'pop'],
#   'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#   'id': '1uNFoZAHBGtllmzznpCI3s',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb8ae7f2aaa9817a704a87ea36',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab676161000051748ae7f2aaa9817a704a87ea36',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f1788ae7f2aaa9817a704a87ea36',
#     'width': 160}],
#   'name': 'Justin Bieber',
#   'popularity': 90,
#   'type': 'artist',
#   'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/4kKPuJwVrBVJyFBDSzx19t'},
#   'followers': {'href': None, 'total': 8},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/4kKPuJwVrBVJyFBDSzx19t',
#   'id': '4kKPuJwVrBVJyFBDSzx19t',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273e893990cf1bf27d6aafdcc40',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02593450df44a7589fde776ba0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851e893990cf1bf27d6aafdcc40',
#     'width': 64}],
#   'name': 'Justin Biberon',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:4kKPuJwVrBVJyFBDSzx19t'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/7fbq53hVW39miuOCYFROd3'},
#   'followers': {'href': None, 'total': 794},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/7fbq53hVW39miuOCYFROd3',
#   'id': '7fbq53hVW39miuOCYFROd3',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb403f98e389fb290daa9b84c8',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174403f98e389fb290daa9b84c8',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178403f98e389fb290daa9b84c8',
#     'width': 160}],
#   'name': 'Justin Biber',
#   'popularity': 21,
#   'type': 'artist',
#   'uri': 'spotify:artist:7fbq53hVW39miuOCYFROd3'}]

# %%
artists['artists']['items'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#  'followers': {'href': None, 'total': 71540268},
#  'genres': ['canadian pop', 'pop'],
#  'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#  'id': '1uNFoZAHBGtllmzznpCI3s',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb8ae7f2aaa9817a704a87ea36',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab676161000051748ae7f2aaa9817a704a87ea36',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f1788ae7f2aaa9817a704a87ea36',
#    'width': 160}],
#  'name': 'Justin Bieber',
#  'popularity': 90,
#  'type': 'artist',
#  'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}

# %%
artist_uri = artists['artists']['items'][0]['uri']
print(artist_uri)
# Out:
# spotify:artist:1uNFoZAHBGtllmzznpCI3s

# %%
results = sp.artist_top_tracks(artist_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    if track['preview_url'] is not None:
        print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : STAY (with Justin Bieber)
# audio    : https://p.scdn.co/mp3-preview/718a2eb032524494a01f73d80af2bcf176c9f3e2?cid=e18fafeb60a949d2a9b7d1efccabe69a
# cover art: https://i.scdn.co/image/ab67616d0000b273b4d59e6fa7e5e7cbc57ac33a
#
# track    : Ghost
# cover art: https://i.scdn.co/image/ab67616d0000b273e6f407c7f3a0ec98845e4431
#
# track    : Love Yourself
# cover art: https://i.scdn.co/image/ab67616d0000b273f46b9d202509a8f7384b90de
#
# track    : Private Landing (feat. Justin Bieber & Future)
# audio    : https://p.scdn.co/mp3-preview/511bdf681359f3b57dfa25344f34c2b66ecc4326?cid=e18fafeb60a949d2a9b7d1efccabe69a
# cover art: https://i.scdn.co/image/ab67616d0000b273feeff698e6090e6b02f21ec0
#
# track    : Peaches (feat. Daniel Caesar & Giveon)
# cover art: https://i.scdn.co/image/ab67616d0000b273e6f407c7f3a0ec98845e4431
#
# track    : bad guy
# cover art: https://i.scdn.co/image/ab67616d0000b273ef6527610d9e59f7cbd0bfe0
#
# track    : Sorry
# cover art: https://i.scdn.co/image/ab67616d0000b273f46b9d202509a8f7384b90de
#
# track    : Baby
# cover art: https://i.scdn.co/image/ab67616d0000b273629dc9e2e3bc20bbd7d92e4a
#
# track    : Beauty And A Beat
# cover art: https://i.scdn.co/image/ab67616d0000b273f1d02a6cec967f8b6b78f76e
#
# track    : Stuck with U (with Justin Bieber)
# cover art: https://i.scdn.co/image/ab67616d0000b2732babb9dbd8f5146112f1bf86

# %%
results['tracks'][0]['preview_url']
# Out:
# 'https://p.scdn.co/mp3-preview/718a2eb032524494a01f73d80af2bcf176c9f3e2?cid=e18fafeb60a949d2a9b7d1efccabe69a'

# %%
from IPython.display import Audio

# %%
Audio(url=results['tracks'][0]['preview_url']+'.mp3', autoplay=False, embed=True)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
